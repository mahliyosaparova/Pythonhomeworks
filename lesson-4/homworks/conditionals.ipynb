# %% [markdown]
# ```
# if <contidion>:
#     <statements>
#     <statements>
# ```

# %%
authenticated = True

if authenticated:
    print("You are logged in")
# Out:
# You are logged in

# %%
authenticated = True

if True:
    print("You are logged in")
# Out:
# You are logged in

# %%
True == True
# Out:
# True

# %%
age = 20

if age > 18:
    print("You are logged in")
# Out:
# You are logged in

# %%
age > 18
# Out:
# True

# %%
age = 0

if age >18:
    print("You are logged in")

# %%
age > 18
# Out:
# False

# %%
age = 10

if age:
    print("You can vote")
# Out:
# You can vote

# %%
age = 0
bool(age)
# Out:
# False

# %% [markdown]
# ```
#     >
#     <
#     ==
#     >=
#     <=
#     !=
# ```

# %%
authenticated = True

if authenticated:
print("You logged in")
# Out:
#   Cell In[42], line 4
#     print("You logged in")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
authenticated = True

if authenticated:
 print("You logged in")
# Out:
# You logged in

# %%
authenticated = True

if authenticated:
    print("You logged in")
    print("Welcome")

print("Outside if statement")
# Out:
# You logged in
# Welcome
# Outside if statement

# %%
authenticated = False

if authenticated:
    print("You logged in")
    print("Welcome")

print("Outside if statement")
# Out:
# Outside if statement

# %%
authenticated = False

if authenticated:
    print("You logged in")
        print("Welcome")
    
print("Outside if statement")
# Out:
#   Cell In[46], line 5
#     print("Welcome")
#     ^
# IndentationError: unexpected indent

# %%
if authenticated:


print("Other stuff")
# Out:
#   Cell In[47], line 4
#     print("Other stuff")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
if authenticated:
    pass

print("Other stuff")
# Out:
# Other stuff

# %%
a = 0
print(bool(a))

if a:
    print('Truthy')
else:
    print("Falthy")
# Out:
# False
# Falthy

# %%
a = 1
print(bool(a))

if a:
    print('Truthy') 
else:
    print("Falthy")
# Out:
# True
# Truthy

# %%
age = None

if age is not None:
    print("Your age is", age)
else:
    print("Age not defined")
# Out:
# Age not defined

# %%
'' == None
# Out:
# False

# %%
'' is None
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\user\AppData\Local\Temp\ipykernel_13060\1115366061.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   '' is None
# False

# %%
0 == None
# Out:
# False

# %%
0 is None
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\user\AppData\Local\Temp\ipykernel_13060\3758039581.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   0 is None
# False

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a # reference assignment

print(a == b)
# Out:
# True

# %%
print(a is b)
# Out:
# False

# %%
x = 5
y = 5

print(x is y)
# Out:
# True

# %%
a = [1, 2, 3]
c = a

print(a is c)
# Out:
# True

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print(a == b)

print("ID a:", id(a)) 
print("ID b:", id(b))
print("ID c:", id(c))
# Out:
# True
# ID a: 2399310888000
# ID b: 2399311272576
# ID c: 2399310888000

# %%
x = 5
y = 5

print("ID x:", id(x))
print("ID y:", id(y))

print(x is y)
# Out:
# ID x: 2399211159920
# ID y: 2399211159920
# True

# %% [markdown]
# - True va True = True
# - True va False = False
# - True yoki False = True

# %%
age = 17
car = 'BMW'

if age >= 18 and car in ['Honda', 'BMW', 'Toyota']:
    print("true")
else:
    print("false")
# Out:
# false

# %%
age = 17
car = 'BMW'

if age >= 18 or car in ['Honda', 'BMW', 'Toyota']:
    print("true")
else:
    print("false")
# Out:
# true

# %%
age = 10

if age < 0:
    print("Incorrect number for age. Age must be positive.")
elif age < 150:
    print("You can vote")
elif age < 18:
    print("You can not vote")
else:
    print("Incorrect number for age. Humans can not live that long.")
# Out:
# You can vote

# %%
if age: print("true"); print("another")
# Out:
# true
# another

# %%
display(1)
# Out:
# 1
